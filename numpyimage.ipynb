# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a blank canvas for the image
width = 400
height = 300
channels = 3
image = np.zeros((height, width, channels), dtype=np.uint8)

#For body
image[100:175 , 100:275 , 0] = 0
image[100:175 , 100:275 , 1] = 128
image[100:175 , 100:275 , 2] = 128

#For eyes
image[110:120 , 250:260 , 0] = 0
image[110:120 , 250:260 , 1] = 0
image[110:120 , 250:260 , 2] = 0

# for Upper beak
image[115:135 , 275:325 , 0] = 255
image[115:135 , 275:325 , 1] = 255
image[115:135 , 275:325 , 2] = 0

# for lower beak
image[137:147 , 275:320 , 0] = 255
image[137:147  , 275:320 , 1] = 255
image[137:147  , 275:320 , 2] = 0

#For leg
image[175:210 , 125:145 , 0] = 255
image[175:210  , 125:145  , 1] = 255
image[175:210  , 125:145  , 2] = 0

image[175:210 , 225:245 , 0] = 255
image[175:210  , 225:245  , 1] = 255
image[175:210  , 225:245  , 2] = 0
 
#For feild 
image[200:300 , : , 0] = 0
image[200:300 , : , 1] =128
image[200:300 , : , 2] = 0

# for tail
image[120:130 ,  50:100 , 0] = 255
image[120:130 ,  50:100, 1] =255
image[120:130 ,  50:100 , 2] = 0

# Display the image
plt.imshow(image)
plt.axis('on')
plt.show()
